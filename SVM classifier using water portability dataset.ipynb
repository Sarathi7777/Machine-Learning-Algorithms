# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score as sc

# %%
data=pd.read_csv('/content/drive/MyDrive/Datasets_ML/water_potability.csv')

# %%
data.head()
# Out:
#          ph    Hardness        Solids  ...  Trihalomethanes  Turbidity  Potability
# 0       NaN  204.890455  20791.318981  ...        86.990970   2.963135           0
# 1  3.716080  129.422921  18630.057858  ...        56.329076   4.500656           0
# 2  8.099124  224.236259  19909.541732  ...        66.420093   3.055934           0
# 3  8.316766  214.373394  22018.417441  ...       100.341674   4.628771           0
# 4  9.092223  181.101509  17978.986339  ...        31.997993   4.075075           0
#
# [5 rows x 10 columns]

# %%
data.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
data.shape
# Out:
# (3276, 10)

# %%
data['ph']=data['ph'].fillna(data['ph'].mean())
data['Sulfate']=data['Sulfate'].fillna(data['Sulfate'].mean())
data['Trihalomethanes']=data['Trihalomethanes'].fillna(data['Trihalomethanes'].mean())
data
# Out:
#             ph    Hardness  ...  Turbidity  Potability
# 0     7.080795  204.890455  ...   2.963135           0
# 1     3.716080  129.422921  ...   4.500656           0
# 2     8.099124  224.236259  ...   3.055934           0
# 3     8.316766  214.373394  ...   4.628771           0
# 4     9.092223  181.101509  ...   4.075075           0
# ...        ...         ...  ...        ...         ...
# 3271  4.668102  193.681735  ...   4.435821           1
# 3272  7.808856  193.553212  ...   2.798243           1
# 3273  9.419510  175.762646  ...   3.298875           1
# 3274  5.126763  230.603758  ...   4.708658           1
# 3275  7.874671  195.102299  ...   2.309149           1
#
# [3276 rows x 10 columns]

# %%
data.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
def detect_outliers(data):
    outlier_indices = set()
    for col in data.select_dtypes(include='number').columns:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR

        outliers = data[(data[col] < lower) | (data[col] > upper)].index
        outlier_indices.update(outliers)

    return data.loc[list(outlier_indices)]

# %%
df=pd.DataFrame(data)
outliers=detect_outliers(df)
print(outliers)
# Out:
#              ph    Hardness  ...  Turbidity  Potability
# 1      3.716080  129.422921  ...   4.500656           0
# 2053   3.846454  211.757205  ...   3.143431           0
# 2054   7.080795  174.917724  ...   3.669057           0
# 9     11.180284  227.231469  ...   4.370562           0
# 2057   5.690387  241.215729  ...   2.988621           0
# ...         ...         ...  ...        ...         ...
# 1989   8.164992  278.340358  ...   4.162496           1
# 2004   7.498372  236.714399  ...   4.242242           1
# 2006   6.538207  214.992866  ...   3.426266           1
# 2012   9.175586  281.594235  ...   2.959685           1
# 2044   7.080795  108.916629  ...   3.895572           1
#
# [610 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               3276 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          3276 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3276 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
sv=SVC(kernel='rbf')
sv.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
ypred=sv.predict(xtest)

# %%
print(sc(ytest,ypred))
# Out:
# 0.6280487804878049

# %%
sv1=SVC(kernel='linear')
sv1.fit(xtrain,ytrain)
ypred1=sv1.predict(xtest)
print(sc(ytest,ypred1))
# Out:
# 0.6189024390243902
